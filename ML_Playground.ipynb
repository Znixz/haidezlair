# %% [markdown]
# <a href="https://colab.research.google.com/github/Znixz/haidezlair/blob/main/ML_Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ucimlrepo
# !pip install matplotlib
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo
#fetch dataset
auto_mpg = fetch_ucirepo(id = 9)
# data as pandas dataframe
x = auto_mpg.data.features
y = auto_mpg.data.targets
z = auto_mpg.data.variables
xyz = auto_mpg.metadata


print(f"Features:\n{x[["weight"]].head(10)}\n\nTarget:\n{y[["mpg"]].head(10)}")

X = x[["weight"]]/1000
Y = y[["mpg"]]
table_XY = pd.concat([X, Y], axis = 1)

display(table_XY.head(10))

plt.scatter(X.head(10), Y.head(10))
plt.xlabel("Pounds in 000")
plt.ylabel("Mile per galon")
plt.show()
# Out:
# Features:
#    weight
# 0    3504
# 1    3693
# 2    3436
# 3    3433
# 4    3449
# 5    4341
# 6    4354
# 7    4312
# 8    4425
# 9    3850
#
# Target:
#     mpg
# 0  18.0
# 1  15.0
# 2  18.0
# 3  16.0
# 4  17.0
# 5  15.0
# 6  14.0
# 7  14.0
# 8  14.0
# 9  15.0
#    weight   mpg
# 0   3.504  18.0
# 1   3.693  15.0
# 2   3.436  18.0
# 3   3.433  16.0
# 4   3.449  17.0
# 5   4.341  15.0
# 6   4.354  14.0
# 7   4.312  14.0
# 8   4.425  14.0
# 9   3.850  15.0

# %%
sample = table_XY.head(77)
display(sample)

plt.scatter(sample["weight"], sample["mpg"])
plt.xlim(0,6)
plt.ylim(0,20)
plt.xlabel("Pound in 000 (Features)")
plt.ylabel("Miles per gallon (Label)")
plt.show()
# Out:
#     weight   mpg
# 0    3.504  18.0
# 1    3.693  15.0
# 2    3.436  18.0
# 3    3.433  16.0
# 4    3.449  17.0
# ..     ...   ...
# 72   3.892  15.0
# 73   4.098  13.0
# 74   4.294  13.0
# 75   4.077  14.0
# 76   2.933  18.0
#
# [77 rows x 2 columns]

# %%
sample = table_XY.head(177)
display(sample)

plt.scatter(sample["weight"], sample["mpg"])
plt.xlim(0,6)
plt.xticks(np.arange(0.0,5.5,0.5))
plt.ylim(0,20)
plt.yticks(np.arange(0.0,40.0,2.0))
plt.xlabel("Pound in 000 (Features)")
plt.ylabel("Miles per gallon (Label)")
plt.show()
# Out:
#      weight   mpg
# 0     3.504  18.0
# 1     3.693  15.0
# 2     3.436  18.0
# 3     3.433  16.0
# 4     3.449  17.0
# ..      ...   ...
# 172   2.223  25.0
# 173   2.545  24.0
# 174   2.984  18.0
# 175   1.937  29.0
# 176   3.211  19.0
#
# [177 rows x 2 columns]

# %%
RX = (x[["weight"]]/1000).rename(columns={"weight": "Pounds in 1000s (Features)"})
RY = (y[["mpg"]]).rename(columns={"mpg": "Miles per gallon (Label)"})
table_RXRY = pd.concat([RX, RY], axis=1)

rsample = table_RXRY.head(177)
display(rsample)

plt.scatter(rsample["Pounds in 1000s (Features)"], rsample["Miles per gallon (Label)"])
plt.xlabel("Pounds in 1000s (Features)")
plt.xlim(0, 6)
plt.xticks(np.arange(0.0,6.0,0.5))
plt.ylabel("Miles per gallon (Label)")
plt.ylim(0, 40)
plt.yticks(np.arange(0, 40, 2))
plt.show()
# Out:
#      Pounds in 1000s (Features)  Miles per gallon (Label)
# 0                         3.504                      18.0
# 1                         3.693                      15.0
# 2                         3.436                      18.0
# 3                         3.433                      16.0
# 4                         3.449                      17.0
# ..                          ...                       ...
# 172                       2.223                      25.0
# 173                       2.545                      24.0
# 174                       2.984                      18.0
# 175                       1.937                      29.0
# 176                       3.211                      19.0
#
# [177 rows x 2 columns]
