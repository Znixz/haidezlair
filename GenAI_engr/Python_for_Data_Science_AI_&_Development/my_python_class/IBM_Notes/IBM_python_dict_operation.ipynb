# %% [markdown]
# <a href="https://colab.research.google.com/github/Znixz/haidezlair/blob/main/GenAI_engr/Python_for_Data_Science_AI_%26_Development/my_python_class/IBM_Notes/IBM_python_dict_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Dictionaries in Python
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *  Create a Dictionary and perform operations on the Dictionary

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#Dictionaries">Dictionaries</a>
#             <ul>
#                 <li><a href="#What-are-Dictionaries?">What are Dictionaries?</a></li>
#                 <li><a href="#Keys">Keys</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="#Quiz-on-Dictionaries">Quiz on Dictionaries</a>
#         </li>
#         <li>
#             <a href="#Scenario">Scenario</a>
#         </li>
#     </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# # Dictionaries

# %% [markdown]
# ## What are Dictionaries?

# %% [markdown]
# A dictionary consists of keys and values. It is helpful to compare a dictionary to a list. Instead of being indexed numerically like a list, dictionaries have keys. These keys are the keys that are used to access values within a dictionary.
#
#
# The best example of a dictionary can be accessing person's detais using the **social security number**.
# Here the social security number which is a unique number will be the **key** and the details of the people will be the **values** associated with it.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/54cVKVMZaWEw7wSCDL8NjQ/DictList1.png" width="650">

# %% [markdown]
# ### Create a Dictionary and access the elements

# %% [markdown]
# An example of a Dictionary <code>Dict</code>:
# Here we are creating a dictionary named **Dict** with he following details
#
# * Keys are **key1, key2, key3, key4, ('key5',), (0, 1)**.
# * Values are {1,2,[3,3,3],(4,4,4),5,6} corresponding to the keys

# %%
# Create the dictionary

Dict = {"key1": 1, "key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), ('key5',): 5, (0, 1): 6}
Dict
# Out:
# {'key1': 1,
#  'key2': '2',
#  'key3': [3, 3, 3],
#  'key4': (4, 4, 4),
#  ('key5',): 5,
#  (0, 1): 6}

# %%
len(Dict["key3"])
Dict["key3"][-1]
# Out:
# 3

# %% [markdown]
# The keys can be strings:

# %%
# Access to the value by the key

Dict["key1"]

# %% [markdown]
# Keys can also be any immutable object such as a tuple:

# %%
# Access to the value by the key

Dict[(0, 1)] #(0, 1) as a key in this situation like other key i.e key1, key2, (0, 1)
# Out:
# 6

# %% [markdown]
# Each key is separated from its value by a colon "<code>:</code>".  Commas separate the items, and the whole dictionary is enclosed in curly braces. An empty dictionary without any items is written with just two curly braces, like this  "<code>{}</code>".

# %%
# Create a sample dictionary

release_year_dict = {"Thriller": "1982", "Back in Black": "1980", \
                    "The Dark Side of the Moon": "1973", "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}
release_year_dict
release_year_dict["Rumours"]
# Out:
# '1977'

# %% [markdown]
# In summary, like a list, a dictionary holds a sequence of elements. Each element is represented by a key and its corresponding value. Dictionaries are created with two curly braces containing keys and values separated by a colon. For every key, there can only be one single value, however,  multiple keys can hold the same value. Keys can only be strings, numbers, or tuples, but values can be any data type.

# %% [markdown]
# It is helpful to visualize the dictionary as a table, as in the following image. The first column represents the keys, the second column represents the values.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%202/images/DictsStructure.png" width="650">

# %% [markdown]
# ## Keys

# %% [markdown]
# You can retrieve the values based on the names:

# %%
# Get value by keys

release_year_dict['Thriller']

# %% [markdown]
# This corresponds to:

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%202/images/DictsKeyOne.png" width="500">

# %% [markdown]
# Similarly for <b>The Bodyguard</b>

# %%
# Get value by key

release_year_dict['The Bodyguard']

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%202/images/DictsKeyTwo.png" width="500">

# %% [markdown]
# Now let us retrieve the keys of the dictionary using the method <code>keys()</code>:

# %%
# Get all the keys in dictionary

release_year_dict.keys()
# Out:
# dict_keys(['Thriller', 'Back in Black', 'The Dark Side of the Moon', 'The Bodyguard', 'Bat Out of Hell', 'Their Greatest Hits (1971-1975)', 'Saturday Night Fever', 'Rumours'])

# %% [markdown]
# You can retrieve the values using the method  <code>values()</code>:

# %%
# Get all the values in dictionary

release_year_dict.values()
# Out:
# dict_values(['1982', '1980', '1973', '1992', '1977', '1976', '1977', '1977'])

# %%
print(list(release_year_dict.values()))
print(list(release_year_dict.keys()))
# Out:
# ['1982', '1980', '1973', '1992', '1977', '1976', '1977', '1977']
# ['Thriller', 'Back in Black', 'The Dark Side of the Moon', 'The Bodyguard', 'Bat Out of Hell', 'Their Greatest Hits (1971-1975)', 'Saturday Night Fever', 'Rumours']

# %%
#v = list(release_year_dict.values()) # create a list of values from the original dict
#k = list(release_year_dict.keys()) # create a list of keys from the original dict
#dict(zip(k, v)) # zip it back to dict

# %% [markdown]
# We can add an entry:

# %%
# Append value with key into dictionary

release_year_dict['Graduation'] = '2007'
release_year_dict

release_year_dict["Noww"] = "2026"
release_year_dict
# Out:
# {'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977',
#  'Graduation': '2007',
#  'Noww': '2026'}

# %% [markdown]
# We can delete an entry:

# %%
# Delete entries by key

del(release_year_dict['Thriller'])
del(release_year_dict['Graduation'])
release_year_dict
# Out:
# {'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977',
#  'now': '2026'}

# %%
del(release_year_dict['Noww'])
release_year_dict
# Out:
# {'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977',
#  'Graduation': '2007'}

# %%
release_year_dict["hello"] = "is here"

# %% [markdown]
# We can verify if an element is in the dictionary:

# %%
# Verify the key is in the dictionary

'The Bodyguard' in release_year_dict
"Noww" in release_year_dict
"hello" in release_year_dict
# Out:
# True

# %% [markdown]
# <hr>

# %% [markdown]
# # Quiz on Dictionaries

# %% [markdown]
# <b>You will need this dictionary for the next two questions:</b>

# %%
# Question sample dictionary

soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}
soundtrack_dic
# Out:
# {'The Bodyguard': '1992', 'Saturday Night Fever': '1977'}

# %% [markdown]
# a) In the dictionary <code>soundtrack_dic</code> what are the keys ?

# %%
# Write your code below and press Shift+Enter to execute
soundtrack_dic.keys()
# Out:
# dict_keys(['The Bodyguard', 'Saturday Night Fever'])

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# soundtrack_dic.keys() # The Keys "The Bodyguard" and "Saturday Night Fever"
#
# ```
#
# </details>

# %% [markdown]
# b) In the dictionary <code>soundtrack_dic</code> what are the values ?

# %%
# Write your code below and press Shift+Enter to execute
soundtrack_dic.values()
# Out:
# dict_values(['1992', '1977'])

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# soundtrack_dic.values() # The values are "1992" and "1977"
#
# ```
#
# </details>

# %% [markdown]
# <hr>

# %% [markdown]
# <b>You will need this dictionary for the following questions:</b>

# %% [markdown]
# The Albums <b>Back in Black</b>, <b>The Bodyguard</b> and <b>Thriller</b> have the following music recording sales in millions 50, 50 and 65 respectively:

# %% [markdown]
# a) Create a dictionary <code>album_sales_dict</code> where the keys are the album name and the sales in millions are the values.

# %%
# Write your code below and press Shift+Enter to execute
album_sales_in_million = {"Back in Black": 50, "The Bodyguard": 50, "Thriller": 65}
album_sales_in_million
# Out:
# {'Back in Black': 50, 'The Bodyguard': 50, 'Thriller': 65}

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}
#
# ```
#
# </details>

# %% [markdown]
# b) Use the dictionary to find the total sales of <b>Thriller</b>:

# %%
# Write your code below and press Shift+Enter to execute
album_sales_in_million["Thriller"]
# Out:
# 65

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# album_sales_dict["Thriller"]
#
# ```
#
# </details>

# %% [markdown]
# c) Find the names of the albums from the dictionary using the method <code>keys()</code>:

# %%
# Write your code below and press Shift+Enter to execute
album_sales_in_million.keys()
# Out:
# dict_keys(['Back in Black', 'The Bodyguard', 'Thriller'])

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# album_sales_dict.keys()
#
# ```
#
# </details>

# %% [markdown]
# d) Find the values of the recording sales from the dictionary using the method <code>values</code>:

# %%
# Write your code below and press Shift+Enter to execute
album_sales_in_million.values()
# Out:
# dict_values([50, 50, 65])

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# album_sales_dict.values()
#
# ```
#
# </details>

# %% [markdown]
# # Scenario

# %% [markdown]
# The inventory store scenario project utilizes a dictionary-based approach to develop a robust system for managing and tracking inventory in a retail store.
# <br>
# **Note:- You will be working with two product details.**

# %% [markdown]
# ## Task-1 Create an empty dictionary

# %% [markdown]
# First you need to create an empty dictionary, where you will be storing the product details.

# %%
#Type your code here
inventory = {}

# %% [markdown]
# <details> <summary>Click here for the solution</summary>
#
# ```python
#
# inventory ={}
#
# ```
#
# </details>

# %% [markdown]
# ## Task-2 Store the first product details in variable
# * Product Name= Mobile phone
# * Product Quantity= 5
# * Product price= 20000
# * Product Release Year= 2020

# %%
#type your code here
Product1_name= "Mobile phone"
Product1_quantity= 5
Product1_price= 20000
Product1_release = 2020

# %% [markdown]
# <details> <summary>Click here for the solution</summary>
#
# ```python
# ProductNo1 = "Mobile Phone"
# ProductNo1_quantity = 5
# ProductNo1_price = 20000
# ProductNo1_releaseYear= 2020
# ```
#
# </details>

# %% [markdown]
# ## Task-3 Add the details in inventory

# %%
#Type your code here
inventory["Product1"]= Product1_Name
inventory["Product1_quantity"]= Product1_quantity
inventory["Product1_price"]= Product1_price
inventory["Product1_release"]=Product1_release

#inventory = {"First product":{"Product Name": "Mobile phone","Product Quantity": 5,
#                              "Product price": 20000,"Product Release Year": 2020}}
#del(inventory["First product"])
inventory
# Out:
# {'ProductNo1': 'Mobile phone',
#  'ProductNo1_quantity': 5,
#  'ProductNo1_price': 20000,
#  'ProductNo1_releaseYear': 2020,
#  'Product2_name': 'Laptop',
#  'Product2_quantity': 10,
#  'Product2_price': 50000,
#  'Product2_release': 2023,
#  'ProductNo1_release': 2020,
#  'Product1': 'Mobile phone',
#  'Product1_quantity': 5,
#  'Product1_price': 20000,
#  'Product1_release': 2020}

# %% [markdown]
# <details> <summary>Click here for the solution</summary>
#
# ```python
#
# inventory["ProductNo1"]= ProductNo1
# inventory["ProductNo1_quantity"]= ProductNo1_quantity
# inventory["ProductNo1_price"]= ProductNo1_price
# inventory["ProductNo1_releaseYear"]=ProductNo1_releaseYear
#
# ```
#
# </details>

# %% [markdown]
# ## Task-4 Store the second product details in a variable.
# * Product Name= "Laptop"
# * Product Quantity= 10
# * Product price = 50000
# * Product Release Year= 2023

# %%
#type your code here
Product2_name= "Laptop"
Product2_quantity= 10
Product2_price = 50000
Product2_release= 2023

# %% [markdown]
# <details> <summary>Click here for the solution</summary>
#
# ```python
#
# ProductNo2 = "Laptop"
# ProductNo2_quantity = 10
# ProductNo2_price = 50000
# ProductNo2_releaseYear= 2023
#
# ```
#
# </details>

# %% [markdown]
# ## Task-5 Add the item detail into the inventory.

# %%
#type your code here
inventory["Product2_name"] = Product2_name
inventory["Product2_quantity"] = Product2_quantity
inventory["Product2_price"] = Product2_price
inventory["Product2_release"] = Product2_release

inventory
# Out:
# {'ProductNo1': 'Mobile phone',
#  'ProductNo1_quantity': 5,
#  'ProductNo1_price': 20000,
#  'ProductNo1_releaseYear': 2020,
#  'Product2_name': 'Laptop',
#  'Product2_quantity': 10,
#  'Product2_price': 50000,
#  'Product2_release': 2023}

# %% [markdown]
# <details> <summary>Click here for the solution</summary>
#
# ```python
#
# inventory["ProductNo2"]= ProductNo2
# inventory["ProductNo2_quantity"]= ProductNo2_quantity
# inventory["ProductNo2_price"]= ProductNo2_price
# inventory["ProductNo2_releaseYear"]=ProductNo2_releaseYear
#
# ```
#
# </details>

# %% [markdown]
# ## Task-6 Display the Products present in the inventory

# %% [markdown]
# Use print statement for displaying the products

# %%
#type your code here
print(inventory)
# Out:
# {'ProductNo1': 'Mobile phone', 'ProductNo1_quantity': 5, 'ProductNo1_price': 20000, 'ProductNo1_releaseYear': 2020, 'Product2_name': 'Laptop', 'Product2_quantity': 10, 'Product2_price': 50000, 'Product2_release': 2023}

# %% [markdown]
# <details> <summary>Click here for the solution</summary>
#
# ```python
#
# print(inventory)
#
# ```
#
# </details>

# %% [markdown]
# ## Task-7 Check if `ProductNo1_releaseYear` and `ProductNo2_releaseYear` is in the inventory

# %%
#Type your code here
print("Product1_release" in inventory)
print("Product2_release" in inventory)
# Out:
# True
# True

# %% [markdown]
# <details> <summary>Click here for the solution</summary>
#
# ```python
#
# print("ProductNo1_releaseYear" in inventory)
# print("ProductNo2_releaseYear" in inventory)
#
# ```
#
# </details>

# %% [markdown]
# **As in inventory `Release year` is not required, let's delete it.**

# %% [markdown]
# ## Task-8 Delete release year of both the products from the inventory

# %%
inventory
# Out:
# {'ProductNo1': 'Mobile phone',
#  'ProductNo1_quantity': 5,
#  'ProductNo1_price': 20000,
#  'ProductNo1_releaseYear': 2020,
#  'Product2_name': 'Laptop',
#  'Product2_quantity': 10,
#  'Product2_price': 50000,
#  'ProductNo1_release': 2020,
#  'Product1': 'Mobile phone',
#  'Product1_quantity': 5,
#  'Product1_price': 20000}

# %%
a = list(inventory.keys())
b = list(inventory.values())
print(len(a))
print(len(b))
# Out:
# 11
# 11

# %%
new = zip(a[4:11], b[4:11])
newdict = dict(new)
del(newdict["ProductNo1_release"])

newdict["Product1_name"] = newdict["Product1"]
del(newdict["Product1"])
newdict
# Out:
# {'Product2_name': 'Laptop',
#  'Product2_quantity': 10,
#  'Product2_price': 50000,
#  'Product1_quantity': 5,
#  'Product1_price': 20000,
#  'Product1_name': 'Mobile phone'}

# %%
#Type your code here
del(inventory["Product1_release"])
del(inventory["Product2_release"])
inventory
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1214/4290989477.py in <cell line: 0>()
#       1 #Type your code here
# ----> 2 del(inventory["Product1_release"])
#       3 del(inventory["Product2_release"])
#       4 inventory
#
# KeyError: 'Product1_release'

# %% [markdown]
# <details> <summary>Click here for the solution</summary>
#
# ```python
#
# del(inventory["ProductNo1_releaseYear"])
# del(inventory["ProductNo2_releaseYear"])
#
# ```
#
# </details>

# %%
inventory = newdict
inventory
# Out:
# {'Product2_name': 'Laptop',
#  'Product2_quantity': 10,
#  'Product2_price': 50000,
#  'Product1_quantity': 5,
#  'Product1_price': 20000,
#  'Product1_name': 'Mobile phone'}

# %% [markdown]
# <hr>
# <h2>The last exercise!</h2>
# <p>Congratulations, you have completed your first lesson and hands-on lab in Python.
# <hr>

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01" target="_blank">Joseph Santarcangelo</a>
#
# ## Other contributors
#
# <a href="https://www.linkedin.com/in/jiahui-mavis-zhou-a4537814a?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">Mavis Zhou</a>
#
# <!--## Change Log--!>
#
# <!--| Date (YYYY-MM-DD) | Version | Changed By    | Change Description                                                  |
# --!>
# <!--| ----------------- | ------- | ------------- | ------------------------------------------------------------------- |
# --!>
# <!--| 2023-05-11        |  2.3    | Akansha yadav | Updated lab with scenario                                           |
# --!>
# <!--|  2022-01-10        | 2.2     | Malika Singla | Removed the readme for GitShare                                     |
# --!>
# <!--| 2020-09-09        | 2.1     | Malika Singla | Updated the variable soundtrack_dict to soundtrack_dic in Questions |
# --!>
# <!--| 2020-08-26        | 2.0     | Lavanya       | Moved lab to course repo in GitLab                                  |
# --!>
# <!--|                   |         |               |                                                                     |
# --!>
# <!--|                   |         |               |                                                                     |
# --!>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
