# %% [markdown]
# <a href="https://colab.research.google.com/github/Znixz/haidezlair/blob/main/GenAI_engr/Python_for_Data_Science_AI_%26_Development/my_python_class/class0/my_python_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Thank you for coming this far.**

# %%
print("testNow")
