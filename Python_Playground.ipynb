# %% [markdown]
# <a href="https://colab.research.google.com/github/Znixz/haidezlair/blob/main/Python_Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Escape backward slash allows the use of a seperate single quote in string without error
print('I\'m Monty Python.')

#Also use of double quotes saves the error of using single quote in line
print("I'm Monty Python.")

print(" \"hellohi\" \"you're\"")
# Out:
# I'm Monty Python.
# I'm Monty Python.
#  "hellohi" "you're"

# %%
print("\"I'm\"\n\"\"learning\"\"\n\"\"\"Python\"\"\"")
# Out:
# "I'm"
# ""learning""
# """Python"""

# %%
#THIS is a seperate project
#from a self learning app, called codino
#Fact, I just copied the solution


#Define decorator and wrapper
def log_activity(func):
    def wrapper(*args, **kwargs):
        print("Starting operation...")
        return func(*args, **kwargs)
    return wrapper


#call the decorator with @
#Define your fnc and
@log_activity
def process_data(data_list):
    for item in data_list:
        yield item.upper()

data = ["apple", "banana", "cherry"]

#Call the fnc
for item in process_data(data):
    print(item)
# Out:
# Starting operation...
# APPLE
# BANANA
# CHERRY

# %%
class Task:
    def __init__(self, title, priority):
        self.title = title
        self.priority = priority
        self.is_done = False

class TodoList:
    def __init__(self):
        self.tasks = []
    def add_task(self, title, priority):
        if not title: raise ValueError('Title cannot be empty')
        task = Task(title, priority)
        self.tasks.append(task)
    def get_tasks(self):
        return self.tasks

def main():
    todo = TodoList()
    try:
        title = 'Buy milk'
        todo.add_task(title, 'High')
        for t in todo.get_tasks():
            print(f'{t.title} [{t.priority}]')
    except Exception as e:
        print(f'Error: {e}')

# %%
class Task:
    def __init__(self, title, priority):
        self.title = title
        self.priority = priority
        self.is_done = False


class TodoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task):
        self.tasks.append(task)

    def get_tasks(self):
        return self.tasks


def main():
    todo = TodoList()

    title = input("Enter task title: ").strip()

    if not title:
        print("Error: Task title cannot be empty.")
        return

    priority = input("Enter task priority: ").strip()

    task = Task(title, priority)
    todo.add_task(task)

    print("\nYour tasks:")

    for task in todo.get_tasks():
        print(f"- {task.title} | Priority: {task.priority}")


main()
# Out:
# Enter task title: stop
# Enter task priority: high
#
# Your tasks:
# - stop | Priority: high

# %%
def get_column_average(filename, col_index):
    try:
        with open(filename, 'r') as f:
            data = f.readlines()
            total = 0
            count = 0
            for line in data[1:]:
                values = line.split(',')
                total += float(values[col_index])
                count += 1
            return total / count
    except IOError:
        print('File not found')
    except ValueError:
        print('Invalid data')

# Usage example:
# print(get_column_average('data.csv', 1))

# %%
import csv

def get_column_average(filename, col_index):
    try:
        with open(filename, "r") as file:
            reader = csv.reader(file)

            next(reader)  # Skip the header

            values = []

            for row in reader:
                try:
                    values.append(float(row[col_index]))
                except ValueError:
                    print("Invalid data")
                    return None

            return sum(values) / len(values)

    except IOError:
        print("File not found")
        return None

# %% [markdown]
# Say you are helping a friend to calculate their weekly paycheck after taxes.
#
# They're in a 12% tax bracket (in other words, 12% of their salary is taken for taxes, and they only take home 88%), and
# They're paid hourly, at a rate of $15/hour.
# The function below calculates the paycheck based on the number of hours worked. The function is more complicated than with the first example, because the function has more lines of code and comments. Similar to the example above, the function has a single argument (num hours). In the function body, we:
#
# Use the value for num_hours to specify the value for a new variable pay_pretax.
# Use the value of pay_pretax to specify the value for a new variable pay_aftertax.
# Return the value of the pay_aftertax variable.

# %%
def get_pay(num_hrs): #define function to calculate pretax pay from total ours work
  pay_pretax = num_hrs * 15  # multiply the total hours with pay per hour $15
  pay_aftertax = pay_pretax * (1 - 0.12) # this line calculate the aftertax of .12
  return pay_aftertax # return the after tax

print(get_pay(50))
print(get_pay(40))

def main(): # define main function
   hrs_work = input("Enter hours work: ").strip()
   try:
      hrs_work = float(hrs_work)
      pay = get_pay(hrs_work)
      print(pay)
   except ValueError:
      print("Error, please enter numeric input")
main()
# Out:
# 660.0
# 528.0
# Enter hours work: 50
# 660.0

# %% [markdown]
# Now you get more variable to work with such as;
# num_hours - number of hours worked in one week
# hourly_wage - the hourly wage (in $/hour)
# tax_bracket - percentage of your salary that is removed for taxes

# %%
def get_pay(num_hrs): #define function to get total ours work
  pay_pretax = num_hrs * 15  # multiply the total hours with pay per hour $15
  pay_aftertax = pay_pretax * (1 - 0.12) # this line calculate the aftertax of .12
  return pay_aftertax # return the after tax

print(get_pay(50))
print(get_pay(40))

def main(): # define main function
   hrs_work = input("Enter hours work: ").strip()
   try:
      hrs_work = float(hrs_work)
      pay = get_pay(hrs_work)
      print(pay)
   except ValueError:
      print("Error, please enter numeric input")
main()
# Out:
# 660.0
# 528.0
# Enter hours work: 50
# 660.0

# %%
def get_pay(num_hrs): #define function to get total ours work
  pay_pretax = num_hrs * 15  # multiply the total hours with pay per hour $15
  pay_aftertax = pay_pretax * (1 - 0.12) # this line calculate the aftertax of .12
  return pay_aftertax # return the after tax

print(get_pay(50))
print(get_pay(40))

def main(): # define main function
   hrs_work = input("Enter hours work: ").strip()
   try:
      hrs_work = float(hrs_work)
      pay = get_pay(hrs_work)
      print(pay)
   except ValueError:
      print("Error, please enter numeric input")
main()
# Out:
# 660.0
# 528.0
# Enter hours work: 50
# 660.0

# %%
def get_pay1(num_hrs, hrs_pay, tax):
  pay_pretax = num_hrs * hrs_pay
  pay_aftertax = pay_pretax * ( 1 - tax/100)
  return pay_aftertax

print(f"${get_pay1(40, 24, 22):.2f}")

def main():
  try:
    hrs_work = float(input("Enter hours work: ").strip())
    hrs_pay = float(input("Enter yuor pay per hour: ").strip())
    tax = float(input("Enter your tax percent i.e 10, 15, 20: ").strip())
    gross = get_pay1(hrs_work, hrs_pay, 0)
    pay = get_pay1(hrs_work, hrs_pay, tax)
    print(f" Gross pay: ${gross:.2f} \n Net pay after tax: ${pay:.2f}")
  except ValueError:
    print("Error, please enter numeric input.")
main()
# Out:
# $748.80
# Enter hours work: 40
# Enter yuor pay per hour: 24
# Enter your tax percent i.e 10, 15, 20: 22
#  Gross pay: $960.00
#  Net pay after tax: $748.80

# %%
def greet():
  print("Hello, goodmorning.")
  print("How are you doing today?")
greet()

def main():
  greet()
main()

print()

def greet1():
  return "HELLO, GOODMORNING.""\n""HOW ARE YOU DOING TODAY?"
print(greet1())

def main1():
  print(greet1())
main1()
# Out:
# Hello, goodmorning.
# How are you doing today?
# Hello, goodmorning.
# How are you doing today?
#
# HELLO, GOODMORNING.
# HOW ARE YOU DOING TODAY?
# HELLO, GOODMORNING.
# HOW ARE YOU DOING TODAY?

# %%
leg_a = float(input(""))
leg_b = float(input(""))
print("Hypotenuse length is " + str((leg_a**2 + leg_b**2) ** .5))
print(type("Hypotenuse length is " + str((leg_a**2 + leg_b**2) ** .5)))
# Out:
# 3
# 4
# Hypotenuse length is 5.0
# <class 'str'>

# %%
var_a = float(input("Enter a value: ").strip())# input a float value for variable a here
var_b = float(input("Enter second value: ").strip())# input a float value for variable b here

add_output = str(var_a + var_b) # output the result of addition here
sub_output = str(var_a - var_b)# output the result of subtraction here
mul_output = str(var_a * var_b)# output the result of multiplication here
div_output = str(var_a / var_b)# output the result of division here

print("addition: " + add_output, "subtraction: " + sub_output, "multiplication: " + mul_output, "division: " + div_output, sep = "\n")
print("\nThat's all, folks!")
# Out:
# Enter a value: 5
# Enter second value: 3
# addition: 8.0
# subtraction: 2.0
# multiplication: 15.0
# division: 1.6666666666666667
#
# That's all, folks!

# %%
# !pip install IPython
# Out:
# Requirement already satisfied: IPython in /usr/local/lib/python3.13/dist-packages (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.13/dist-packages (from IPython) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.13/dist-packages (from IPython) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from IPython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from IPython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.13/dist-packages (from IPython) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from IPython) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from IPython) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from IPython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.13/dist-packages (from IPython) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from IPython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->IPython) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.8.2)

# %%
#The image below is load as reference to the following code
#y = 1 / (x + (1 / (x + (1 /( x + (1 / x ))))))
from IPython.display import Image, display
display(Image(url="https://www.netacad.com/content/pe1/1.0/courses/content/m2/en-US/assets/ae5d9dec1dda05fda93912c1d7191ee42d10c8e5.png"))
# Out:
# <img src="https://www.netacad.com/content/pe1/1.0/courses/content/m2/en-US/assets/ae5d9dec1dda05fda93912c1d7191ee42d10c8e5.png"/>

# %%
x = float(input("Enter value for x: "))

y = 1 / (x + (1 / (x + (1 /( x + (1 / x ))))))# Write your code here.

print("y =", y)
# Out:
# Enter value for x: 10
# y = 0.09901951266867294

# %%
### Note:The program repeatedly accepts `x`, validates that it is numeric and not zero using `try/except`
## and a `while` loop, calculates `y`, and asks the user whether to continue.
##`continue` restarts the outer loop when invalid input is entered.**
##THE Y EQUATION IS DERIVE FROM THE IMAGE LOADED ABOVE

start = 1
while start == 1:
  try:
    x = float(input("Enter value for x: "))
    while x == 0:
      print("Error! x can not be  0.")
      print()

      x = float(input("Enter value for x: "))
  except ValueError:
    print("Error! x can not be  non numeric.")
    print()
    continue

  y = 1 / (x + (1 / (x + (1 /( x + (1 / x ))))))# Write your code here.
  print("y =", y)

  start = input("continue checking? (y/n): ")
  print()
  start = 0 if start == "n" else 1
# Out:
# Enter value for x: wjey
# Error! x can not be  non numeric.
#
# Enter value for x: 0
# Error! x can not be  0.
#
# Enter value for x: 9
# y = 0.1097722263041881
# continue checking? (y/n): y
#
# Enter value for x: 7
# y = 0.14005492349941154
# continue checking? (y/n): n

# %%
x = input()
y = input()
print(x + y)
# Out:
# 2
# 4
# 24

# %%
x1 = int(input())
y1 = int(input())

x1 = x1 / y1
y1 = y1 / x1

print(y1)
# Out:
# 2
# 4
# 8.0

# %%
x = int(input())
y = int(input())

x = x % y
x = x % y
y = y % x

print(y)
# Out:
# 11
# 4
# 1

# %%
x = input()
y = int(input())

print(x * y)
# Out:
# 3
# 6
# 333333

# %%
z = y = x = 1
print(x, y, z, sep='*')
# Out:
# 1*1*1

# %%
y = 2 + 3 * 5.
print(y)
# Out:
# 17.0

# %%
x = 1 / 2 + 3 // 3 + 4 ** 2
print(x)
# Out:
# 17.5

# %%
x = int(input())
y = int(input())

print(x + y)
# Out:
# 2
# 4
# 6

# %%
hour = int(input("Starting time (hours): "))
mins = int(input("Starting time (minutes): "))
dura = int(input("Event duration (minutes): "))
time_after = hour*60 + mins + dura
hour = (time_after // 60) % 24
mins = time_after % 60

print(hour,mins, sep = ":")
# Out:
# Starting time (hours): 0
# Starting time (minutes): 1
# Event duration (minutes): 2939
# 1:0

# %%
hour = int(input("Starting time (hours): "))
mins = int(input("Starting time (minutes): "))
dura = int(input("Event duration (minutes): "))

# Write your code here.
hour = hour + ((mins + dura) // 60) % 24
mins = (mins + dura) % 60
print(hour, mins, sep = ":")
# Out:
# Starting time (hours): 0
# Starting time (minutes): 1
# Event duration (minutes): 2939
# 1:0

# %%
a = "Hello"
b = "Hello"

print( a == b, a is b, b is a, b == a)
# Out:
# True True True True

# %%
n = int(input("Enter a number: "))
print(n >= 100)
# Out:
# Enter a number: +123
# True

# %%
# Read three numbers
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))
number3 = int(input("Enter the third number: "))

# We temporarily assume that the first number
# is the largest one.
# We will verify this soon.
largest_number = number1

# We check if the second number is larger than the current largest_number
# and update the largest_number if needed.
if number2 > largest_number:
    largest_number = number2

# We check if the third number is larger than the current largest_number
# and update the largest_number if needed.
if number3 > largest_number:
    largest_number = number3

# Print the result
print("The largest number is:", largest_number)
# Out:
# Enter the first number: 1
# Enter the second number: 2
# Enter the third number: 3
# The largest number is: 3

# %%
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the first number: "))
number3 = int(input("Enter the first number: "))

largest_number = number3

if number2 > largest_number:
    largest_number = number2

if number1 > largest_number:
    largest_number = number1

print("Largest number is:", largest_number)
# Out:
# Enter the first number: 5
# Enter the first number: 7
# Enter the first number: 3
# Largest number is: 7

# %%
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the first number: "))
number3 = int(input("Enter the first number: "))

largestnumber = max(number1, number2, number3)

print("Largest number is:", largestnumber)
# Out:
# Enter the first number: 54
# Enter the first number: 734
# Enter the first number: 827
# Largest number is: 827

# %%
name = input("Enter flower name: ")

if name == "Spathiphyllum":
    print("Yes - Spathiphyllum is the best plant ever!")
elif name == "spathiphyllum":
    print("No, I want a big Spathiphyllum!")
else:
    print("Spathiphyllum! Not", name + "!")
# Out:
# Enter flower name: ierou
# Spathiphyllum! Not ierou!

# %%
income = float(input("Enter the annual income: "))

if income <= 85528:
	tax = income * 0.18 - 556.02

if income > 85528:
    tax = 14839.02 + 0.32 * (income - 85528) # Write the rest of your code here.

if tax < 0:
    tax = 0.00
tax = round(tax, 0)
print("The tax is:", tax, "thalers")
# Out:
# Enter the annual income: 85528
# The tax is: 14839.0 thalers

# %%
####CORRECTION

income = float(input("Enter the annual income: "))

if income < 85528:
	tax = income * 0.18 - 556.02
else:
	tax = (income - 85528) * 0.32 + 14839.02

if tax < 0.0:
	tax = 0.0

tax = round(tax, 0)
print("The tax is:", tax, "thalers")
# Out:
# Enter the annual income: 85528
# The tax is: 14839.0 thalers

# %%
year = int(input("Enter a year: "))

if year < 1582:
	print("Not within the Gregorian calendar period")
else:
	if year % 4 != 0:
		print("Common year")
	elif year % 100 != 0:
		print("Leap year")
	elif year % 400 != 0:
		print("Common year")
	else:
		print("Leap year")

# %%
### WORKING WITH WHILE LOOP

# Store the current largest number here.
largest_number = -999999999

# Input the first value.
number = int(input("Enter a number or type -1 to stop: "))

# If the number is not equal to -1, continue.
while number != -1:
    # Is number larger than largest_number?
    if number > largest_number:
        # Yes, update largest_number.
        largest_number = number
    # Input the next number.
    number = int(input("Enter a number or type -1 to stop: "))

# Print the largest number.
print("The largest number is:", largest_number)
# Out:
# Enter a number or type -1 to stop: -387587634589890239897356
# Enter a number or type -1 to stop: -3756357897238534975678
# Enter a number or type -1 to stop: -1
# The largest number is: -999999999

# %%
# A program that reads a sequence of numbers
# and counts how many numbers are even and how many are odd.
# The program terminates when zero is entered.

odd_numbers = 0
even_numbers = 0

# Read the first number.
number = int(input("Enter a number or type 0 to stop: "))

# 0 terminates execution.
while number != 0:
    # Check if the number is odd.
    if number % 2 == 1:
        # Increase the odd_numbers counter.
        odd_numbers += 1
    else:
        # Increase the even_numbers counter.
        even_numbers += 1
    # Read the next number.
    number = int(input("Enter a number or type 0 to stop: "))

# Print results.
print("Odd numbers count:", odd_numbers)
print("Even numbers count:", even_numbers)
# Out:
# Enter a number or type 0 to stop: 8
# Enter a number or type 0 to stop: 687
# Enter a number or type 0 to stop: 66
# Enter a number or type 0 to stop: 8
# Enter a number or type 0 to stop: 2
# Enter a number or type 0 to stop: 784
# Enter a number or type 0 to stop: 0
# Odd numbers count: 1
# Even numbers count: 5
# 5

# %%
secret_number = 777

print(
"""
+================================+
| Welcome to my game, muggle!    |
| Enter an integer number        |
| and guess what number I've     |
| picked for you.                |
| So, what is the secret number? |
+================================+
""")

user_num = int(input("Enter a number: ").strip())

while user_num != secret_number:
    print("Ha ha! You're stuck in my loop!")
    user_num = int(input("Enter a number: ").strip())
print("Well done, muggle! You are free now.")
# Out:
# +================================+
# | Welcome to my game, muggle!    |
# | Enter an integer number        |
# | and guess what number I've     |
# | picked for you.                |
# | So, what is the secret number? |
# +================================+
#
# Enter a number: 777
# Well done, muggle! You are free now.

# %%
for i in range(10):
    print("The value of i is currently", i)
    print("The value of i is currently", i + 1)
    print("The value of i is currently", 10 - i)
# Out:
# The value of i is currently 0
# The value of i is currently 1
# The value of i is currently 10
# The value of i is currently 1
# The value of i is currently 2
# The value of i is currently 9
# The value of i is currently 2
# The value of i is currently 3
# The value of i is currently 8
# The value of i is currently 3
# The value of i is currently 4
# The value of i is currently 7
# The value of i is currently 4
# The value of i is currently 5
# The value of i is currently 6
# The value of i is currently 5
# The value of i is currently 6
# The value of i is currently 5
# The value of i is currently 6
# The value of i is currently 7
# The value of i is currently 4
# The value of i is currently 7
# The value of i is currently 8
# The value of i is currently 3
# The value of i is currently 8
# The value of i is currently 9
# The value of i is currently 2
# The value of i is currently 9
# The value of i is currently 10
# The value of i is currently 1

# %%
for i in range(2, 8):
    print("The value of i is currently", i)
# Out:
# The value of i is currently 2
# The value of i is currently 3
# The value of i is currently 4
# The value of i is currently 5
# The value of i is currently 6
# The value of i is currently 7

# %%
for i in range(2, 8, 3):
    print("The value of i is currently", i)
# Out:
# The value of i is currently 2
# The value of i is currently 5

# %%
for i in range(1, 1):
    print("The value of i is currently", i)

# %%
power = 1
for expo in range(16):
    print("2 to the power of", expo, "is", power)
    power *= 2
# Out:
# 2 to the power of 0 is 1
# 2 to the power of 1 is 2
# 2 to the power of 2 is 4
# 2 to the power of 3 is 8
# 2 to the power of 4 is 16
# 2 to the power of 5 is 32
# 2 to the power of 6 is 64
# 2 to the power of 7 is 128
# 2 to the power of 8 is 256
# 2 to the power of 9 is 512
# 2 to the power of 10 is 1024
# 2 to the power of 11 is 2048
# 2 to the power of 12 is 4096
# 2 to the power of 13 is 8192
# 2 to the power of 14 is 16384
# 2 to the power of 15 is 32768

# %%
for expo in range(16):
    print("2 to the power of", expo, "is", 2**expo)
# Out:
# 2 to the power of 0 is 1
# 2 to the power of 1 is 2
# 2 to the power of 2 is 4
# 2 to the power of 3 is 8
# 2 to the power of 4 is 16
# 2 to the power of 5 is 32
# 2 to the power of 6 is 64
# 2 to the power of 7 is 128
# 2 to the power of 8 is 256
# 2 to the power of 9 is 512
# 2 to the power of 10 is 1024
# 2 to the power of 11 is 2048
# 2 to the power of 12 is 4096
# 2 to the power of 13 is 8192
# 2 to the power of 14 is 16384
# 2 to the power of 15 is 32768

# %% [markdown]
# Your task is very simple here: write a program that uses a for loop to "count mississippily" to five. Having counted to five, the program should print to the screen the final message "Ready or not, here I come!"
#
# 1 Mississippi
# 2 Mississippi
# 3 Mississippi
# 4 Mississippi
# 5 Mississippi
# Ready or not, here I come!

# %%
import time

for count in range(5):# Write a for loop that counts to five.
    print(count + 1, "Mississippi")# Body of the loop - print the loop iteration number and the word "Mississippi".
    time.sleep(1)# Body of the loop - use: time.sleep(1)

print("Ready or not, here I come!")# Write a print function with the final message.
# Out:
# 1 Mississippi
# 2 Mississippi
# 3 Mississippi
# 4 Mississippi
# 5 Mississippi
# Ready or not, here I come!

# %%
# break - example

print("The break instruction:")
for i in range(1, 6):
    if i == 3:
        break
    print("Inside the loop.", i)
print("Outside the loop.")
# Out:
# The break instruction:
# Inside the loop. 1
# Inside the loop. 2
# Outside the loop.

# %%
# continue - example

print("\nThe continue instruction:")
for i in range(1, 6):
    if i == 3:
        continue
    print("Inside the loop.", i)
print("Outside the loop.")
# Out:
# The continue instruction:
# Inside the loop. 1
# Inside the loop. 2
# Inside the loop. 4
# Inside the loop. 5
# Outside the loop.

# %%
largest_number = -99999999
counter = 0

while True:
    number = int(input("Enter a number or type -1 to end the program: "))
    if number == -1:
        break
    counter += 1
    if number > largest_number:
        largest_number = number

if counter != 0:
    print("The largest number is", largest_number)
else:
    print("You haven't entered any number.")
# Out:
# Enter a number or type -1 to end the program: 1
# Enter a number or type -1 to end the program: 2
# Enter a number or type -1 to end the program: -1
# The largest number is 2

# %%
largest_number = -99999999
counter = 0

number = int(input("Enter a number or type -1 to end program: "))

while number != -1:
    if number == -1:
        continue
    counter += 1

    if number > largest_number:
        largest_number = number
    number = int(input("Enter a number or type -1 to end the program: "))

if counter:
    print("The largest number is", largest_number)
else:
    print("You haven't entered any number.")

# %%
secretword = input("Enter the secret word: ").strip()

while True:
  if secretword != "chupacabra":
    print("incorrect")
    secretword = input("Enter the secret word: ").strip()
  else:
    break
print("Well done, muggle! You are free now.")
# Out:
# Enter the secret word: yofwei
# incorrect
# Enter the secret word: uiwefgodus
# incorrect
# Enter the secret word: gfsd\uo
# incorrect
# Enter the secret word: chupacabra
# Well done, muggle! You are free now.

# %%
while True:
  secretword = input("Enter the secret word: ").strip()
  if secretword != "chupacabra":
    print("incorrect")
  else:
    break
print("Well done, muggle! You are free now.")
# Out:
# Enter the secret word: ihwefio
# incorrect
# Enter the secret word: juhwfiow
# incorrect
# Enter the secret word: jaefguo
# incorrect
# Enter the secret word: chupacabra
# Well done, muggle! You are free now.

# %%
while True:
  secretword = input("Enter the secret word: ").strip()
  if secretword != "chupacabra":
    print("incorrect")
  else:
    break
print("You've successfully left the loop.")
# Out:
# Enter the secret word: oirusey
# incorrect
# Enter the secret word: sgvc
# incorrect
# Enter the secret word: chupacabra
# You've successfully left the loop.

# %%
while True:
  secretword = input("Enter the secret word: ").strip()
  if secretword == "chupacabra":
    break
print("You've successfully left the loop.")
# Out:
# Enter the secret word: iugdui
# Enter the secret word: fgyyiwef
# Enter the secret word: chupacabra
# You've successfully left the loop.

# %%
# Prompt the user to enter a word
# and assign it to the user_word variable.
user_word = (input("Enter a word: ").strip()).upper()
for letter in user_word:
    # Complete the body of the for loop.
    if letter == "A":
        continue
    elif letter == "E":
        continue
    elif letter == "I":
        continue
    elif letter == "O":
        continue
    elif letter == "U":
        continue
    else:
        print(letter, end = "-")
# Out:
# Enter a word: IOUEA

# %% [markdown]
# Scenario
# Listen to this story: a boy and his father, a computer programmer, are playing with wooden blocks. They are building a pyramid.
#
# Their pyramid is a bit weird, as it is actually a pyramid-shaped wall – it's flat. The pyramid is stacked according to one simple principle: each lower layer contains one block more than the layer above.
#
#
# The figure illustrates the rule used by the builders:

# %%
from IPython.display import Image, display

# %%
display(Image(url="https://www.netacad.com/content/pe1/1.0/courses/content/m3/en-US/assets/3fe9e03670b96fc65999f8d7ba1a478ac1812790.png"))
# Out:
# <img src="https://www.netacad.com/content/pe1/1.0/courses/content/m3/en-US/assets/3fe9e03670b96fc65999f8d7ba1a478ac1812790.png"/>

# %% [markdown]
# Your task is to write a program which reads the number of blocks the builders have, and outputs the height of the pyramid that can be built using these blocks.
#
# Note: the height is measured by the number of fully completed layers – if the builders don't have a sufficient number of blocks and cannot complete the next layer, they finish their work immediately.
#
# Test your code using the data we've provided.

# %%
blocks = int(input("Enter the number of blocks: "))

height = 0 #
# Write your code here.
#
i = 1
while i <= blocks:
  height += 1
  blocks -= i
  i += 1
print("The height of the pyramid:", height)
# Out:
# Enter the number of blocks: 6
# The height of the pyramid: 3

# %% [markdown]
# In 1937, a German mathematician named Lothar Collatz formulated an intriguing hypothesis (it still remains unproven) which can be described in the following way:
#
# Write a program which reads one natural number and executes the above steps as long as c0 remains different from 1. We also want you to count the steps needed to achieve the goal. Your code should output all the intermediate values of c0, too.
#
# Hint: the most important part of the problem is how to transform Collatz's idea into a while loop – this is the key to success.
#
# Test your code using the data we've provided.

# %%
#take any non-negative and non-zero integer number and name it c0;
#if it's even, evaluate a new c0 as c0 ÷ 2;
#otherwise, if it's odd, evaluate a new c0 as 3 × c0 + 1;
#if c0 ≠ 1, go back to point 2

steps = 0
c0 = int(input("Enter any non negative integer: "))
while c0 != 1:
    steps += 1
    print(c0)
    if c0 % 2 == 0:
        c0 = int(c0 / 2)
    else:
        c0 = 3 * c0 + 1
print("steps =", steps)
# Out:
# Enter any non negative integer: 15
# 15
# 46
# 23
# 70
# 35
# 106
# 53
# 160
# 80
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# steps = 17
